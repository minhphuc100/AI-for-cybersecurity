# %%
#supervised learning
#which means the data is labeled, and we can use it to train an ai model to make predictions or classifications based on that data.
#for example, if we have a dataset of images of cats and dogs, we can label each image as either "cat" or "dog".
#then we can use this labeled dataset to train a supervised learning model, such as a convolutional neural network (CNN), to learn the features that distinguish cats from dogs.
#once the model is trained, we can use it to make predictions on new, unlabeled images, and it will be able to classify them as either "cat" or "dog" based on what it has learned from the training data.

# viec gan nhan, neu du lieu qua lon, thi viec gan nhan co the mat thoi gian va cong suc, va do do co the su dung cac ky thuat khac nhau de tu dong gan nhan cho du lieu, nhu la su dung cac mo hinh may hoc de du doan nhan cho du lieu moi, hoac su dung cac ky thuat gan nhan tu dong de gan nhan cho du lieu da co san.
# VD, nhu thay bao la ta co the dua dataset cho nhieu mo hinh may hoc khac nhau, va su dung ket qua du doan tu cac mo hinh do de gan nhan cho du lieu moi, hoac su dung cac ky thuat gan nhan tu dong de gan nhan cho du lieu da co san, nhu la su dung cac mo hinh clustering de gan nhan cho du lieu da co san, hoac su dung cac mo hinh deep learning de gan nhan cho du lieu moi.
